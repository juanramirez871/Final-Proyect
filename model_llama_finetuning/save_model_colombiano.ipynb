# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
from huggingface_hub import login

# %%
BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B-Instruct"
LORA_PATH = "./llama_ventas_colombiano_LoRA"
OUTPUT_PATH = "./llama_ventas_colombiano_merged"

# %%
login("API_KEY")

# %%
model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    torch_dtype=torch.bfloat16,
    device_map="cpu"
)

model = PeftModel.from_pretrained(model, LORA_PATH)
model = model.merge_and_unload()
model.save_pretrained(OUTPUT_PATH)

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
tokenizer.save_pretrained(OUTPUT_PATH)
# Out:
# ...
# Writing model shards: 100%|██████████| 1/1 [02:58<00:00, 178.57s/it]
# ('./llama_ventas_colombiano_merged/tokenizer_config.json',
#  './llama_ventas_colombiano_merged/chat_template.jinja',
#  './llama_ventas_colombiano_merged/tokenizer.json')

# %%
# !python -m mlx_lm convert --hf-path "$PWD/llama_ventas_colombiano_merged" --mlx-path "$PWD/llama_ventas_colombiano_mlx_q8" -q --q-bits 8
